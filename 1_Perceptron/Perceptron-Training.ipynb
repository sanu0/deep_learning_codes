# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('placement.xlsx')
print(df.head())
# Out:
#    cgpa  resume_score  placed
# 0   6.6          8.72       1
# 1   6.7          5.43       0
# 2   6.9          8.12       1
# 3   7.0          6.87       0
# 4   7.1          7.45       0

# %%
print(df.shape)
df.head()
# Out:
# (44, 3)
#    cgpa  resume_score  placed
# 0   6.6          8.72       1
# 1   6.7          5.43       0
# 2   6.9          8.12       1
# 3   7.0          6.87       0
# 4   7.1          7.45       0

# %%
# sns.scatterplot(df['cgpa'],df['resume_score'],hue=df['placed'])

sns.scatterplot(x=df['cgpa'], y=df['resume_score'], hue=df['placed'])
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
X = df.iloc[:,0:2]
Y = df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()

# %%
p.fit(X,Y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[14.5 , -7.66]])

# %%
p.intercept_
# Out:
# array([-42.])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X.values, Y.values, clf=p,legend=2)
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
